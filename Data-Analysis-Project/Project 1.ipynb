# %%
import os
import glob
import pandas as pd
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')  
import warnings
warnings.filterwarnings('ignore')

# %%
abj = pd.read_csv("https://raw.githubusercontent.com/Dav-lopez/Data-Analysis-Project/main/Abuja_Branch.csv")

# %%
abj
# Out:
#       Invoice ID Branch   City Customer type  Gender            Product line  \
# 0    692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1    351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2    529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3    299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4    319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
# ..           ...    ...    ...           ...     ...                     ...
# 327  552-44-5977      B  Abuja        Member    Male       Health and beauty
# 328  430-53-4718      B  Abuja        Member    Male       Health and beauty
# 329  602-16-6955      B  Abuja        Normal  Female       Sports and travel
# 330  690-01-6631      B  Abuja        Normal    Male     Fashion accessories
# 331  303-96-2227      B  Abuja        Normal  Female      Home and lifestyle
#
# ...

# %%
lag = pd.read_csv("https://raw.githubusercontent.com/Dav-lopez/Data-Analysis-Project/main/Lagos_Branch.csv")

# %%
lag
# Out:
#       Invoice ID Branch   City Customer type  Gender            Product line  \
# 0    750-67-8428      A  Lagos        Member  Female       Health and beauty
# 1    631-41-3108      A  Lagos        Normal    Male      Home and lifestyle
# 2    123-19-1176      A  Lagos        Member    Male       Health and beauty
# 3    373-73-7910      A  Lagos        Normal    Male       Sports and travel
# 4    355-53-5943      A  Lagos        Member  Female  Electronic accessories
# ..           ...    ...    ...           ...     ...                     ...
# 335  886-18-2897      A  Lagos        Normal  Female      Food and beverages
# 336  745-74-0715      A  Lagos        Normal    Male  Electronic accessories
# 337  727-02-1313      A  Lagos        Member    Male      Food and beverages
# 338  347-56-2442      A  Lagos        Normal    Male      Home and lifestyle
# 339  849-09-3807      A  Lagos        Member  Female     Fashion accessories
#
# ...

# %%
ph = pd.read_csv("https://raw.githubusercontent.com/Dav-lopez/Data-Analysis-Project/main/Port_Harcourt_Branch.csv")

# %%
ph
# Out:
#       Invoice ID Branch           City Customer type  Gender  \
# 0    226-31-3081      C  Port Harcourt        Normal  Female
# 1    699-14-3026      C  Port Harcourt        Normal    Male
# 2    315-22-5665      C  Port Harcourt        Normal  Female
# 3    300-71-4605      C  Port Harcourt        Member    Male
# 4    183-56-6882      C  Port Harcourt        Member  Female
# ..           ...    ...            ...           ...     ...
# 323  148-41-7930      C  Port Harcourt        Normal    Male
# 324  189-40-5216      C  Port Harcourt        Normal    Male
# 325  267-62-7380      C  Port Harcourt        Member    Male
# 326  652-49-6720      C  Port Harcourt        Member  Female
# 327  233-67-5758      C  Port Harcourt        Normal    Male
#
#                Product line  Unit price  Quantity    Tax 5%      Total  \
# 0    Electronic accessories      5500.8         5   1375.20   28879.20
# 1    Electronic accessories     30740.4         7  10759.14  225941.94
# ...

# %%
joined_files = pd.concat([ph,lag,abj])

# %%
df = joined_files

# %%
df
# Out:
#       Invoice ID Branch           City Customer type  Gender  \
# 0    226-31-3081      C  Port Harcourt        Normal  Female
# 1    699-14-3026      C  Port Harcourt        Normal    Male
# 2    315-22-5665      C  Port Harcourt        Normal  Female
# 3    300-71-4605      C  Port Harcourt        Member    Male
# 4    183-56-6882      C  Port Harcourt        Member  Female
# ..           ...    ...            ...           ...     ...
# 327  552-44-5977      B          Abuja        Member    Male
# 328  430-53-4718      B          Abuja        Member    Male
# 329  602-16-6955      B          Abuja        Normal  Female
# 330  690-01-6631      B          Abuja        Normal    Male
# 331  303-96-2227      B          Abuja        Normal  Female
#
#                Product line  Unit price  Quantity    Tax 5%      Total  \
# 0    Electronic accessories      5500.8         5   1375.20   28879.20
# 1    Electronic accessories     30740.4         7  10759.14  225941.94
# ...

# %%
df.head()
# Out:
#     Invoice ID Branch           City Customer type  Gender  \
# 0  226-31-3081      C  Port Harcourt        Normal  Female
# 1  699-14-3026      C  Port Harcourt        Normal    Male
# 2  315-22-5665      C  Port Harcourt        Normal  Female
# 3  300-71-4605      C  Port Harcourt        Member    Male
# 4  183-56-6882      C  Port Harcourt        Member  Female
#
#              Product line  Unit price  Quantity    Tax 5%      Total  \
# 0  Electronic accessories      5500.8         5   1375.20   28879.20
# 1  Electronic accessories     30740.4         7  10759.14  225941.94
# 2      Home and lifestyle     26481.6        10  13240.80  278056.80
# 3  Electronic accessories     30974.4         5   7743.60  162615.60
# 4      Food and beverages     35791.2         4   7158.24  150323.04
#
#         Date   Time Payment      cogs  gross margin percentage  gross income  \
# 0   3/8/2019  10:29    Cash   27504.0                 4.761905       1375.20
# ...

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.columns.values.tolist()
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Unit price',
#  'Quantity',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'Payment',
#  'cogs',
#  'gross margin percentage',
#  'gross income',
#  'Rating']

# %%
df.describe()
# Out:
#          Unit price     Quantity        Tax 5%          Total           cogs  \
# count   1000.000000  1000.000000   1000.000000    1000.000000    1000.000000
# mean   20041.966800     5.510000   5536.572840  116268.029640  110731.456800
# std     9538.066205     2.923431   4215.177173   88518.720636   84303.543463
# min     3628.800000     1.000000    183.060000    3844.260000    3661.200000
# 25%    11835.000000     3.000000   2132.955000   44792.055000   42659.100000
# 50%    19882.800000     5.000000   4351.680000   91385.280000   87033.600000
# 75%    28056.600000     8.000000   8080.290000  169686.090000  161605.800000
# max    35985.600000    10.000000  17874.000000  375354.000000  357480.000000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00   5536.572840     6.97270
# std               6.131498e-14   4215.177173     1.71858
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Invoice ID                 1000
# Branch                     1000
# City                       1000
# Customer type              1000
# Gender                     1000
# Product line               1000
# Unit price                 1000
# Quantity                   1000
# Tax 5%                     1000
# Total                      1000
# Date                       1000
# Time                       1000
# Payment                    1000
# cogs                       1000
# gross margin percentage    1000
# gross income               1000
# Rating                     1000
# dtype: int64

# %%
df.notna()
# Out:
#      Invoice ID  Branch  City  Customer type  Gender  Product line  \
# 0          True    True  True           True    True          True
# 1          True    True  True           True    True          True
# 2          True    True  True           True    True          True
# 3          True    True  True           True    True          True
# 4          True    True  True           True    True          True
# ..          ...     ...   ...            ...     ...           ...
# 327        True    True  True           True    True          True
# 328        True    True  True           True    True          True
# 329        True    True  True           True    True          True
# 330        True    True  True           True    True          True
# 331        True    True  True           True    True          True
#
#      Unit price  Quantity  Tax 5%  Total  Date  Time  Payment  cogs  \
# 0          True      True    True   True  True  True     True  True
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 331
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
date1 = pd.to_datetime(df["Date"])

# %%
date1
# Out:
# 0     2019-03-08
# 1     2019-03-25
# 2     2019-02-24
# 3     2019-02-25
# 4     2019-02-06
#          ...
# 327   2019-01-03
# 328   2019-01-28
# 329   2019-01-24
# 330   2019-02-22
# 331   2019-03-02
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
type(date1)
# Out:
# pandas.core.series.Series

# %%
time = pd.to_datetime(df["Time"])

# %%
time
# Out:
# 0     2022-04-11 10:29:00
# 1     2022-04-11 18:30:00
# 2     2022-04-11 11:38:00
# 3     2022-04-11 11:24:00
# 4     2022-04-11 10:42:00
#               ...
# 327   2022-04-11 19:08:00
# 328   2022-04-11 15:46:00
# 329   2022-04-11 18:10:00
# 330   2022-04-11 18:35:00
# 331   2022-04-11 17:16:00
# Name: Time, Length: 1000, dtype: datetime64[ns]

# %%
type(time)
# Out:
# pandas.core.series.Series

# %%
Nwday = date1.dt.day

# %%
Nwday
# Out:
# 0       8
# 1      25
# 2      24
# 3      25
# 4       6
#        ..
# 327     3
# 328    28
# 329    24
# 330    22
# 331     2
# Name: Date, Length: 1000, dtype: int64

# %%
Nwmonth = date1.dt.month

# %%
Nwmonth
# Out:
# 0      3
# 1      3
# 2      2
# 3      2
# 4      2
#       ..
# 327    1
# 328    1
# 329    1
# 330    2
# 331    3
# Name: Date, Length: 1000, dtype: int64

# %%
Nwhour = time.dt.hour

# %%
Nwhour
# Out:
# 0      10
# 1      18
# 2      11
# 3      11
# 4      10
#        ..
# 327    19
# 328    15
# 329    18
# 330    18
# 331    17
# Name: Time, Length: 1000, dtype: int64

# %%
Nwyar = date1.dt.year

# %%
Nwyar
# Out:
# 0      2019
# 1      2019
# 2      2019
# 3      2019
# 4      2019
#        ...
# 327    2019
# 328    2019
# 329    2019
# 330    2019
# 331    2019
# Name: Date, Length: 1000, dtype: int64

# %%
Nwhour.nunique()
# Out:
# 11

# %%
Nwhour.unique()
# Out:
# array([10, 18, 11, 12, 13, 20, 19, 17, 15, 16, 14], dtype=int64)

# %%
categorical_columns = [col for col in df.columns
                       if df[col].dtype == "object" ]

# %%
categorical_columns
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Date',
#  'Time',
#  'Payment']

# %%
df['Invoice ID'].unique().tolist(),
df['City'].unique().tolist()
df['Customer type'].unique().tolist()
df['Gender'].unique().tolist()
df['Product line'].unique().tolist()
df['Date'].unique().tolist()
df['Time'].unique().tolist()
df['Payment'].unique().tolist()
# Out:
# ['Cash', 'Epay', 'Card']

# %%
df['Invoice ID'].unique().tolist()
# Out:
# ['226-31-3081',
#  '699-14-3026',
#  '315-22-5665',
#  '300-71-4605',
#  '183-56-6882',
#  '232-16-2483',
#  '333-73-7901',
#  '554-53-8700',
#  '228-96-1411',
#  '617-15-4209',
#  '574-22-5561',
#  '326-78-5178',
#  '778-71-5554',
#  '399-46-5918',
#  '120-06-4233',
#  '285-68-5083',
#  '803-83-5989',
#  '838-78-4295',
#  '393-65-2792',
#  '796-12-2025',
#  '841-35-6630',
#  '732-94-0499',
#  '263-10-3913',
#  '829-49-1914',
#  '756-01-7507',
#  '870-72-4431',
#  '480-63-2856',
#  '787-56-0757',
#  '360-39-5055',
#  '730-50-9884',
#  '362-58-8315',
#  '565-80-5980',
#  '225-32-0908',
#  '512-91-0811',
#  '871-39-9221',
#  '163-56-7055',
#  '189-98-2939',
#  '551-21-3069',
#  '628-34-3388',
#  '588-01-7461',
#  '861-77-0145',
#  '210-67-5886',
#  '237-01-6122',
#  '225-98-1496',
#  '659-36-1684',
#  '336-78-2147',
#  '189-08-9157',
#  '663-86-9076',
#  '483-71-1164',
#  '597-78-7908',
#  '731-81-9469',
#  '280-17-4359',
#  '338-65-2210',
#  '488-25-4221',
#  '458-41-1477',
# ...

# %%
df['City'].unique().tolist()
# Out:
# ['Port Harcourt', 'Lagos', 'Abuja']

# %%
df['Customer type'].unique().tolist()
# Out:
# ['Normal', 'Member']

# %%
df['Product line'].unique().tolist()
# Out:
# ['Electronic accessories',
#  'Home and lifestyle',
#  'Food and beverages',
#  'Sports and travel',
#  'Health and beauty',
#  'Fashion accessories']

# %%
df['Gender'].unique().tolist()
# Out:
# ['Female', 'Male']

# %%
len(df['Gender'].unique())
# Out:
# 2

# %%
len(df['Product line'].unique())
# Out:
# 6

# %%
df['Product line'].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
df['Customer type'].value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer type, dtype: int64

# %%
df['Payment'].value_counts()
# Out:
# Epay    345
# Cash    344
# Card    311
# Name: Payment, dtype: int64

# %%
City_grp = df.groupby('City').sum()

# %%
City_grp
# Out:
#                Unit price  Quantity      Tax 5%        Total        cogs  \
# City
# Abuja           6652396.8      1820  1820531.52  38231161.92  36410630.4
# Lagos           6705176.4      1859  1820577.78  38232133.38  36411555.6
# Port Harcourt   6684393.6      1831  1895463.54  39804734.34  37909270.8
#
#                gross margin percentage  gross income  Rating
# City
# Abuja                      1580.952381    1820531.52  2263.6
# Lagos                      1619.047619    1820577.78  2389.2
# Port Harcourt              1561.904762    1895463.54  2319.9

# %%
df.groupby('City').mean()
# Out:
#                  Unit price  Quantity       Tax 5%          Total  \
# City
# Abuja          20037.339759  5.481928  5483.528675  115154.102169
# Lagos          19721.107059  5.467647  5354.640529  112447.451118
# Port Harcourt  20379.248780  5.582317  5778.852256  121355.897378
#
#                         cogs  gross margin percentage  gross income    Rating
# City
# Abuja          109670.573494                 4.761905   5483.528675  6.818072
# Lagos          107092.810588                 4.761905   5354.640529  7.027059
# Port Harcourt  115577.045122                 4.761905   5778.852256  7.072866

# %%
df.groupby('gross income')['City'].max()
# Out:
# gross income
# 183.06      Port Harcourt
# 217.62              Lagos
# 225.72      Port Harcourt
# 230.04      Port Harcourt
# 251.64      Port Harcourt
#                 ...
# 17528.40            Abuja
# 17550.00    Port Harcourt
# 17733.60    Port Harcourt
# 17816.40            Lagos
# 17874.00    Port Harcourt
# Name: City, Length: 990, dtype: object

# %%
df.groupby(['City'])['gross income'].max()
# Out:
# City
# Abuja            17528.4
# Lagos            17816.4
# Port Harcourt    17874.0
# Name: gross income, dtype: float64

# %%
df.groupby(['City'])['gross income'].mean().sort_values(ascending=False)
# Out:
# City
# Port Harcourt    5778.852256
# Abuja            5483.528675
# Lagos            5354.640529
# Name: gross income, dtype: float64

# %%
df.groupby(['Product line'])['gross income'].max()
# Out:
# Product line
# Electronic accessories    16156.26
# Fashion accessories       17874.00
# Food and beverages        17733.60
# Health and beauty         16290.00
# Home and lifestyle        17550.00
# Sports and travel         17179.20
# Name: gross income, dtype: float64

# %%
df.groupby(['Product line'])['Gender'].value_counts()
# Out:
# Product line            Gender
# Electronic accessories  Male      86
#                         Female    84
# Fashion accessories     Female    96
#                         Male      82
# Food and beverages      Female    90
#                         Male      84
# Health and beauty       Male      88
#                         Female    64
# Home and lifestyle      Male      81
#                         Female    79
# Sports and travel       Female    88
#                         Male      78
# Name: Gender, dtype: int64

# %%
df.groupby(['Product line'])['Customer type'].value_counts()
# Out:
# Product line            Customer type
# Electronic accessories  Normal           92
#                         Member           78
# Fashion accessories     Normal           92
#                         Member           86
# Food and beverages      Member           94
#                         Normal           80
# Health and beauty       Normal           79
#                         Member           73
# Home and lifestyle      Member           83
#                         Normal           77
# Sports and travel       Member           87
#                         Normal           79
# Name: Customer type, dtype: int64

# %%
df.groupby(['Payment'])['gross income'].mean().sort_values(ascending=False)
# Out:
# Payment
# Cash    5591.689535
# Card    5554.455048
# Epay    5465.496000
# Name: gross income, dtype: float64

# %%
df.groupby(['Branch'])['gross income'].mean().sort_values(ascending=False)
# Out:
# Branch
# C    5778.852256
# B    5483.528675
# A    5354.640529
# Name: gross income, dtype: float64

# %%
df.groupby('City')['Quantity'].mean()
# Out:
# City
# Abuja            5.481928
# Lagos            5.467647
# Port Harcourt    5.582317
# Name: Quantity, dtype: float64

# %%
sns.countplot(x = 'City' , data=df).set_title("Sales Records")
# Out:
# Text(0.5, 1.0, 'Sales Records')

# %%
sns.countplot(x='Quantity', hue='City', data=df).set_title("Sales Records/Quantity")
# Out:
# Text(0.5, 1.0, 'Sales Records Quantity')

# %%
sns.countplot(x='Payment', data=df).set_title("Payment Method")
# Out:
# Text(0.5, 1.0, 'Payment Method')

# %%
sns.countplot(x='Payment', hue='City', data=df).set_title("Payment Method/ state")
# Out:
# Text(0.5, 1.0, 'Payment Method/ state')

# %%
sns.countplot(y='Product line', data=df).set_title("Sales Records")
# Out:
# Text(0.5, 1.0, 'Sales Records')

# %%
sns.countplot(y='Product line', hue='Payment', data=df).set_title("Product analysis")
# Out:
# Text(0.5, 1.0, 'Product analysis')
